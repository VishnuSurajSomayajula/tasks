# %%
import pandas as pd

# %%
naveen = pd.read_csv("all-weeks-countries.csv")

# %%
naveen.head(10)
# Out:
#   country_name country_iso2        week category  weekly_rank  \
# 0    Argentina           AR  2022-04-17    Films            1
# 1    Argentina           AR  2022-04-17    Films            2
# 2    Argentina           AR  2022-04-17    Films            3
# 3    Argentina           AR  2022-04-17    Films            4
# 4    Argentina           AR  2022-04-17    Films            5
# 5    Argentina           AR  2022-04-17    Films            6
# 6    Argentina           AR  2022-04-17    Films            7
# 7    Argentina           AR  2022-04-17    Films            8
# 8    Argentina           AR  2022-04-17    Films            9
# 9    Argentina           AR  2022-04-17    Films           10
#
#                     show_title season_title  cumulative_weeks_in_top_10
# 0               The In Between          NaN                           2
# 1                     All Hail          NaN                           3
# ...

# %%
naveen.tail(10)
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 78810      Vietnam           VN  2021-07-04       TV            1
# 78811      Vietnam           VN  2021-07-04       TV            2
# 78812      Vietnam           VN  2021-07-04       TV            3
# 78813      Vietnam           VN  2021-07-04       TV            4
# 78814      Vietnam           VN  2021-07-04       TV            5
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                  show_title                    season_title  \
# 78810                  Mine                  Mine: Season 1
# 78811     Hospital Playlist     Hospital Playlist: Season 1
# ...

# %%
naveen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78820 entries, 0 to 78819
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_name                78820 non-null  object
#  1   country_iso2                78820 non-null  object
#  2   week                        78820 non-null  object
#  3   category                    78820 non-null  object
#  4   weekly_rank                 78820 non-null  int64
#  5   show_title                  78820 non-null  object
#  6   season_title                38991 non-null  object
#  7   cumulative_weeks_in_top_10  78820 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 4.8+ MB

# %%
naveen = pd.read_csv("all-weeks-countries.csv",delimiter=';')
naveen
# Out:
#       country_name,country_iso2,week,category,weekly_rank,show_title,season_title,cumulative_weeks_in_top_10
# 0      Argentina,AR,2022-04-17,Films,1,The In Between,,2
# 1            Argentina,AR,2022-04-17,Films,2,All Hail,,3
# 2      Argentina,AR,2022-04-17,Films,3,A Score to Set...
# 3             Argentina,AR,2022-04-17,Films,4,Furioza,,2
# 4      Argentina,AR,2022-04-17,Films,5,The Taming of ...
# ...                                                  ...
# 78815  Vietnam,VN,2021-07-04,TV,6,Reply 1988,Reply 19...
# 78816  Vietnam,VN,2021-07-04,TV,7,"Nevertheless,","Ne...
# 78817  Vietnam,VN,2021-07-04,TV,8,Too Hot to Handle,T...
# 78818  Vietnam,VN,2021-07-04,TV,9,Record of Ragnarok,...
# 78819  Vietnam,VN,2021-07-04,TV,10,Crash Landing on Y...
#
# [78820 rows x 1 columns]

# %%
naveen.head()
# Out:
#   country_name,country_iso2,week,category,weekly_rank,show_title,season_title,cumulative_weeks_in_top_10
# 0  Argentina,AR,2022-04-17,Films,1,The In Between,,2
# 1        Argentina,AR,2022-04-17,Films,2,All Hail,,3
# 2  Argentina,AR,2022-04-17,Films,3,A Score to Set...
# 3         Argentina,AR,2022-04-17,Films,4,Furioza,,2
# 4  Argentina,AR,2022-04-17,Films,5,The Taming of ...

# %%
naveen = pd.read_csv("all-weeks-countries.csv")

# %%
naveen
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AR  2022-04-17    Films            1
# 1        Argentina           AR  2022-04-17    Films            2
# 2        Argentina           AR  2022-04-17    Films            3
# 3        Argentina           AR  2022-04-17    Films            4
# 4        Argentina           AR  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between                             NaN
# ...

# %%
naveen.isnull().sum()
# Out:
# country_name                      0
# country_iso2                      0
# week                              0
# category                          0
# weekly_rank                       0
# show_title                        0
# season_title                  39829
# cumulative_weeks_in_top_10        0
# dtype: int64

# %%
naveen.isnull()
# Out:
#        country_name  country_iso2   week  category  weekly_rank  show_title  \
# 0             False         False  False     False        False       False
# 1             False         False  False     False        False       False
# 2             False         False  False     False        False       False
# 3             False         False  False     False        False       False
# 4             False         False  False     False        False       False
# ...             ...           ...    ...       ...          ...         ...
# 78815         False         False  False     False        False       False
# 78816         False         False  False     False        False       False
# 78817         False         False  False     False        False       False
# 78818         False         False  False     False        False       False
# 78819         False         False  False     False        False       False
#
#        season_title  cumulative_weeks_in_top_10
# ...

# %%
naveen.isnull().sum()
# Out:
# country_name                      0
# country_iso2                      0
# week                              0
# category                          0
# weekly_rank                       0
# show_title                        0
# season_title                  39829
# cumulative_weeks_in_top_10        0
# dtype: int64

# %%
naveen
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AR  2022-04-17    Films            1
# 1        Argentina           AR  2022-04-17    Films            2
# 2        Argentina           AR  2022-04-17    Films            3
# 3        Argentina           AR  2022-04-17    Films            4
# 4        Argentina           AR  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between                             NaN
# ...

# %%
naveen.fillna(value = 'Season Not Avilable ')
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AR  2022-04-17    Films            1
# 1        Argentina           AR  2022-04-17    Films            2
# 2        Argentina           AR  2022-04-17    Films            3
# 3        Argentina           AR  2022-04-17    Films            4
# 4        Argentina           AR  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between            Season Not Avilable
# ...

# %%
naveen['category'].values
# Out:
# array(['Films', 'Films', 'Films', ..., 'TV', 'TV', 'TV'], dtype=object)

# %%
naveen = naveen.replace('AR','AG',regex=True)
naveen.head(10)
naveen.dtypes
# Out:
# country_name                  object
# country_iso2                  object
# week                          object
# category                      object
# weekly_rank                    int64
# show_title                    object
# season_title                  object
# cumulative_weeks_in_top_10     int64
# dtype: object

# %%
naveen
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AG  2022-04-17    Films            1
# 1        Argentina           AG  2022-04-17    Films            2
# 2        Argentina           AG  2022-04-17    Films            3
# 3        Argentina           AG  2022-04-17    Films            4
# 4        Argentina           AG  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between                             NaN
# ...

# %%
naveen
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AG  2022-04-17    Films            1
# 1        Argentina           AG  2022-04-17    Films            2
# 2        Argentina           AG  2022-04-17    Films            3
# 3        Argentina           AG  2022-04-17    Films            4
# 4        Argentina           AG  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between                             NaN
# ...

# %%
naveen.fillna(value = 'Season Not Available ')
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AG  2022-04-17    Films            1
# 1        Argentina           AG  2022-04-17    Films            2
# 2        Argentina           AG  2022-04-17    Films            3
# 3        Argentina           AG  2022-04-17    Films            4
# 4        Argentina           AG  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between           Season Not Available
# ...

# %%
# !pip install matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %%
i=display(naveen[naveen.category=='Films'])
i
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AG  2022-04-17    Films            1
# 1        Argentina           AG  2022-04-17    Films            2
# 2        Argentina           AG  2022-04-17    Films            3
# 3        Argentina           AG  2022-04-17    Films            4
# 4        Argentina           AG  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78805      Vietnam           VN  2021-07-04    Films            6
# 78806      Vietnam           VN  2021-07-04    Films            7
# 78807      Vietnam           VN  2021-07-04    Films            8
# 78808      Vietnam           VN  2021-07-04    Films            9
# 78809      Vietnam           VN  2021-07-04    Films           10
#
#                        show_title season_title  cumulative_weeks_in_top_10
# 0                  The In Between          NaN                           2
# ...

# %%
naveen.fillna(value = 'Season Not Available ')
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AG  2022-04-17    Films            1
# 1        Argentina           AG  2022-04-17    Films            2
# 2        Argentina           AG  2022-04-17    Films            3
# 3        Argentina           AG  2022-04-17    Films            4
# 4        Argentina           AG  2022-04-17    Films            5
# ...            ...          ...         ...      ...          ...
# 78815      Vietnam           VN  2021-07-04       TV            6
# 78816      Vietnam           VN  2021-07-04       TV            7
# 78817      Vietnam           VN  2021-07-04       TV            8
# 78818      Vietnam           VN  2021-07-04       TV            9
# 78819      Vietnam           VN  2021-07-04       TV           10
#
#                      show_title                    season_title  \
# 0                The In Between           Season Not Available
# ...

# %%
Films = naveen[naveen.category=='Films']

# %%
plt.bar(Films['weekly_rank'],Films['cumulative_weeks_in_top_10'])
plt.title('show ranking daily')
plt.ylabel('ranking')
plt.gcf().set_size_inches(7,8)
plt.xticks(rotation=90)
plt.show()

# %%
display(naveen["country_name"].value_counts())
# Out:
# Argentina     840
# Norway        840
# Qatar         840
# Portugal      840
# Poland        840
#              ...
# Guatemala     840
# Guadeloupe    840
# Greece        840
# Germany       840
# Russia        700
# Name: country_name, Length: 94, dtype: int64

# %%
display(naveen["season_title"].value_counts())
# Out:
# Squid Game: Season 1                                   1198
# Money Heist: Part 5                                     870
# Maid: Limited Series                                    712
# Inventing Anna: Limited Series                          704
# Yo soy Betty, la fea: Season 1                          615
#                                                        ...
# The World's Most Amazing Vacation Rentals: Season 1       1
# Rick and Morty: Season 1                                  1
# The K2: Season 1                                          1
# A Korean Odyssey: Season 1                                1
# My Sassy Girl: Season 1                                   1
# Name: season_title, Length: 844, dtype: int64

# %%
country_name = naveen["country_name"].value_counts().head(10).values
country_iso2  = naveen["country_name"].value_counts().head(10).index
plt.gcf().set_size_inches(20,11)
plt.pie(country_name,labels=country_iso2 ,autopct="%1.1f%%",wedgeprops={'edgecolor':'black'})
plt.title('top 10')
plt.show()
