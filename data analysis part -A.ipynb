# %%
import pandas as pd

# %%
dataset = pd.read_csv("students_adaptability_level_online_education.csv",delimiter=';')
dataset
# Out:
#      Gender,Age,Education Level,Institution Type,IT Student,Location,Load-shedding,Financial Condition,Internet Type,Network Type,Class Duration,Self Lms,Device,Adaptivity Level
# 0     Boy,21-25,University,Non Government,No,Yes,Low...
# 1     Girl,21-25,University,Non Government,No,Yes,Hi...
# 2     Girl,16-20,College,Government,No,Yes,Low,Mid,W...
# 3     Girl,11-15,School,Non Government,No,Yes,Low,Mi...
# 4     Girl,16-20,School,Non Government,No,Yes,Low,Po...
# ...                                                 ...
# 1200  Girl,16-20,College,Non Government,No,Yes,Low,M...
# 1201  Girl,16-20,College,Non Government,No,No,High,M...
# 1202  Boy,11-15,School,Non Government,No,Yes,Low,Mid...
# 1203  Girl,16-20,College,Non Government,No,No,Low,Mi...
# 1204  Girl,11-15,School,Non Government,No,Yes,Low,Po...
#
# [1205 rows x 1 columns]

# %%
dataset = pd.read_csv("students_adaptability_level_online_education.csv")

# %%
dataset.head(10)
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
# 5    Boy  11-15          School   Non Government         No      Yes
# 6    Boy  11-15          School   Non Government         No      Yes
# 7    Boy  11-15          School   Non Government         No      Yes
# 8    Boy  16-20         College       Government         No      Yes
# 9    Boy  11-15          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# ...

# %%
dataset.tail(10)
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 1195    Boy  21-25      University   Non Government        Yes      Yes
# 1196    Boy  16-20         College       Government         No       No
# 1197    Boy  21-25      University   Non Government        Yes      Yes
# 1198    Boy  16-20         College       Government        Yes       No
# 1199    Boy  21-25      University   Non Government        Yes      Yes
# 1200   Girl  16-20         College   Non Government         No      Yes
# 1201   Girl  16-20         College   Non Government         No       No
# 1202    Boy  11-15          School   Non Government         No      Yes
# 1203   Girl  16-20         College   Non Government         No       No
# 1204   Girl  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# 1195          High                Poor          Wifi           4G
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1205 non-null   object
#  1   Age                  1205 non-null   object
#  2   Education Level      1205 non-null   object
#  3   Institution Type     1205 non-null   object
#  4   IT Student           1205 non-null   object
#  5   Location             1205 non-null   object
#  6   Load-shedding        1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Class Duration       1205 non-null   object
#  11  Self Lms             1205 non-null   object
#  12  Device               1205 non-null   object
#  13  Adaptivity Level     1205 non-null   object
# dtypes: object(14)
# memory usage: 131.9+ KB

# %%
dataset.head()
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0
#
#   Self Lms  Device Adaptivity Level
# 0       No     Tab         Moderate
# ...

# %%
s = dataset.drop(["Self Lms","Device","Adaptivity Level"],axis='columns',inplace=True)

# %%
dataset
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 0       Boy  21-25      University   Non Government         No      Yes
# 1      Girl  21-25      University   Non Government         No      Yes
# 2      Girl  16-20         College       Government         No      Yes
# 3      Girl  11-15          School   Non Government         No      Yes
# 4      Girl  16-20          School   Non Government         No      Yes
# ...     ...    ...             ...              ...        ...      ...
# 1200   Girl  16-20         College   Non Government         No      Yes
# 1201   Girl  16-20         College   Non Government         No       No
# 1202    Boy  11-15          School   Non Government         No      Yes
# 1203   Girl  16-20         College   Non Government         No       No
# 1204   Girl  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Gender                 0
# Age                    0
# Education Level        0
# Institution Type       0
# IT Student             0
# Location               0
# Load-shedding          0
# Financial Condition    0
# Internet Type          0
# Network Type           0
# Class Duration         0
# dtype: int64

# %%
dataset.dropna(axis=0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Gender                 0
# Age                    0
# Education Level        0
# Institution Type       0
# IT Student             0
# Location               0
# Load-shedding          0
# Financial Condition    0
# Internet Type          0
# Network Type           0
# Class Duration         0
# dtype: int64

# %%
dataset['Education Level'].values
# Out:
# array(['University', 'University', 'College', ..., 'School', 'College',
#        'School'], dtype=object)

# %%
datset=dataset.replace('college','colleges',regex=True)
dataset.head(10)
dataset.dtypes
# Out:
# Gender                 object
# Age                    object
# Education Level        object
# Institution Type       object
# IT Student             object
# Location               object
# Load-shedding          object
# Financial Condition    object
# Internet Type          object
# Network Type           object
# Class Duration         object
# dtype: object

# %%
dataset['Education Level'].values
# Out:
# array(['University', 'University', 'College', ..., 'School', 'College',
#        'School'], dtype=object)

# %%
def value_to_float(x):
    if 'G' in x:
        if len(x)>1:
            return float(x.replace('G',' '))*1
        dataset['G last Change']=dataset['G last Change'].apply(value_to_float)

# %%
dataset.head()
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0

# %%
dataset.dtypes
# Out:
# Gender                 object
# Age                    object
# Education Level        object
# Institution Type       object
# IT Student             object
# Location               object
# Load-shedding          object
# Financial Condition    object
# Internet Type          object
# Network Type           object
# Class Duration         object
# dtype: object

# %%
# !pip install matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %%
i=display(dataset[dataset.Gender=='Boy'])
i
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 0       Boy  21-25      University   Non Government         No      Yes
# 5       Boy  11-15          School   Non Government         No      Yes
# 6       Boy  11-15          School   Non Government         No      Yes
# 7       Boy  11-15          School   Non Government         No      Yes
# 8       Boy  16-20         College       Government         No      Yes
# ...     ...    ...             ...              ...        ...      ...
# 1196    Boy  16-20         College       Government         No       No
# 1197    Boy  21-25      University   Non Government        Yes      Yes
# 1198    Boy  16-20         College       Government        Yes       No
# 1199    Boy  21-25      University   Non Government        Yes      Yes
# 1202    Boy  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# ...

# %%
dataset.head(10)
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
# 5    Boy  11-15          School   Non Government         No      Yes
# 6    Boy  11-15          School   Non Government         No      Yes
# 7    Boy  11-15          School   Non Government         No      Yes
# 8    Boy  16-20         College       Government         No      Yes
# 9    Boy  11-15          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration
# 0           Low                 Mid          Wifi           4G            3-6
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')

# %%
i=display(dataset[dataset.Gender=='Boy'])
i
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 0       Boy  21-25      University   Non Government         No      Yes
# 5       Boy  11-15          School   Non Government         No      Yes
# 6       Boy  11-15          School   Non Government         No      Yes
# 7       Boy  11-15          School   Non Government         No      Yes
# 8       Boy  16-20         College       Government         No      Yes
# ...     ...    ...             ...              ...        ...      ...
# 1196    Boy  16-20         College       Government         No       No
# 1197    Boy  21-25      University   Non Government        Yes      Yes
# 1198    Boy  16-20         College       Government        Yes       No
# 1199    Boy  21-25      University   Non Government        Yes      Yes
# 1202    Boy  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# ...

# %%
Boy=dataset[dataset.Gender=='Boy']

# %%
plt.bar(Boy['Age'],Boy['Education Level'])
plt.title('student sytem')
plt.ylabel('student ages')
#plt.gcf().set_size_iches(6,6)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(dataset['Gender'],dataset['Institution Type'],color='#00FFFF')
plt.title('minory student')
plt.ylabel("Institution Type")
plt.xlabel("Gender")
plt.gcf().set_size_inches(6,7)
plt.show()

# %%
plt.barh(dataset['Gender'],dataset['Institution Type'],color='#00FFFF')
plt.title('minory student')
plt.ylabel("Gender")
plt.xlabel("Institution Type")
plt.gcf().set_size_inches(15,7)
plt.show()

# %%
display(dataset["Education Level"].value_counts())
# Out:
# School        530
# University    456
# College       219
# Name: Education Level, dtype: int64

# %%
display(dataset["Internet Type"].value_counts())
# Out:
# Mobile Data    695
# Wifi           510
# Name: Internet Type, dtype: int64

# %%
Education_Level=dataset["Education Level"].value_counts().head(10).values
Age = dataset["Education Level"].value_counts().head(10).index
plt.gcf().set_size_inches(20,11)
plt.pie(Education_Level,labels=Age,autopct="%1.1f%%",wedgeprops={'edgecolor':'black'})
plt.title('top 10')
plt.show()
